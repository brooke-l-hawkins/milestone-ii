# %% [markdown]
# ## Set up

# %% [markdown]
# Set up libraries and load data.

# %%
import numpy as np
import pandas as pd
import scipy.sparse
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
import pickle

# %%
# load tweet dataframes
train_vectors = scipy.sparse.load_npz('../data/derived/tweets_supervised_train_vectors_count.npz')
dev_vectors   = scipy.sparse.load_npz('../data/derived/tweets_supervised_dev_vectors_count.npz')

# load count vectors
train_df = pd.read_csv('../data/derived/tweets_supervised_train.csv')
dev_df   = pd.read_csv('../data/derived/tweets_supervised_dev.csv')

# %% [markdown]
# Confirm data size and format is as expected.

# %%
# check size of dataframes
for df in [train_df, dev_df]:
    print(f'{len(df)} records.')

# check shape and format of vectors
for vectors in [train_vectors, dev_vectors]:
    print(f'{vectors.shape}    {type(vectors)}')
# Out:
# 6497 records.
# 1393 records.
# (6497, 14740)    <class 'scipy.sparse.csr.csr_matrix'>
# (1393, 14740)    <class 'scipy.sparse.csr.csr_matrix'>

# %% [markdown]
# Create random seed to use as needed.

# %%
# create global variable to use for random seed as needed
random_seed = 466

# %% [markdown]
# ## Train decision tree classifier

# %%
def train_decision_tree(features, labels, random_seed):
    """
    Train decision tree classifier with provided features, labels, and random seed
    """
    
    # initialize classifier with default arguments
    decision_tree = DecisionTreeClassifier(random_state = random_seed)
    # train classifier
    decision_tree.fit(X = features, y = labels)
    
    return decision_tree

# %%
# train decision tree
decision_tree = train_decision_tree(features = train_vectors, labels = train_df['label'], random_seed = random_seed)

# %%
# save decision tree
pickle.dump(decision_tree, open('../data/derived/decision_tree.pkl', 'wb'))

# %% [markdown]
# ## Train support vector classifier

# %%
def train_linear_svc(features, labels, random_seed):
    """
    Train support vector classifier with linear kernel with provided features, labels, and random seed
    """
    # initialize classifier with default arguments
    linear_svc = LinearSVC(random_state = random_seed)
    # train classifier
    linear_svc.fit(X = features, y = labels)
    
    return linear_svc

# %%
# train support vector classifier
linear_svc = train_linear_svc(features = train_vectors, labels = train_df['label'], random_seed = random_seed)

# %%
# save support vector classifier
pickle.dump(linear_svc, open('../data/derived/linear_svc.pkl', 'wb'))

# %% [markdown]
# ## Train multilayer perceptron

# %%
def train_multilayer_perceptron(features, labels, random_seed):
    """
    Train multilayer perceptron with provided features, labels, and random seed
    """
    # initialize classifier with default arguments
    multilayer_perceptron = MLPClassifier(random_state = random_seed)
    # train classifier
    multilayer_perceptron.fit(X = features, y = labels)
    
    return multilayer_perceptron

# %%
# %%time

# train multilayer perceptron
multilayer_perceptron = train_multilayer_perceptron(features = train_vectors, labels = train_df['label'], random_seed = random_seed)
# Out:
# CPU times: user 35.7 s, sys: 9.04 s, total: 44.8 s
# Wall time: 44.8 s

# %%
# save multilayer perceptron
pickle.dump(multilayer_perceptron, open('../data/derived/multilayer_perceptron.pkl', 'wb'))

# %% [markdown]
# ## Generate predictions with classifiers

# %%
def generate_predictions(model, features):
    """
    Generate predictions with trained decision tree classifier
    """
    
    # generate predictions with classifier
    predictions = model.predict(X = features)
    
    return predictions

def save_predictions(tweet_ids, labels, predictions, filepath_out):
    """
    Write predictions to CSV
    """
    
    # create dataframe with record IDs, labels, and predicted labels
    df = pd.DataFrame(data={'tweet_id':tweet_ids, 'label':labels, 'prediction':predictions})
    # write dataframe to file
    df.to_csv(filepath_out, index=False)

# %%
# generate predictions for decision tree
train_predictions_decision_tree = generate_predictions(model = decision_tree, features = train_vectors)
dev_predictions_decision_tree   = generate_predictions(model = decision_tree, features = dev_vectors)

# write predictions to CSV
save_predictions(tweet_ids = train_df['tweet_id'],
                 labels = train_df['label'],
                 predictions = train_predictions_decision_tree,
                 filepath_out = '../data/derived/tweets_supervised_train_predictions_decision_tree.csv')
save_predictions(tweet_ids = dev_df['tweet_id'],
                 labels = dev_df['label'],
                 predictions = dev_predictions_decision_tree,
                 filepath_out = '../data/derived/tweets_supervised_dev_predictions_decision_tree.csv')

# %%
# generate predictions for support vector classifier
train_predictions_linear_svc = generate_predictions(model = linear_svc, features = train_vectors)
dev_predictions_linear_svc   = generate_predictions(model = linear_svc, features = dev_vectors)

# write predictions to CSV
save_predictions(tweet_ids = train_df['tweet_id'],
                 labels = train_df['label'],
                 predictions = train_predictions_linear_svc,
                 filepath_out = '../data/derived/tweets_supervised_train_predictions_linear_svc.csv')
save_predictions(tweet_ids = dev_df['tweet_id'],
                 labels = dev_df['label'],
                 predictions = dev_predictions_linear_svc,
                 filepath_out = '../data/derived/tweets_supervised_dev_predictions_linear_svc.csv')

# %%
# generate predictions for multilayer perceptron
train_predictions_multilayer_perceptron = generate_predictions(model = multilayer_perceptron, features = train_vectors)
dev_predictions_multilayer_perceptron   = generate_predictions(model = multilayer_perceptron, features = dev_vectors)

# write predictions to CSV
save_predictions(tweet_ids = train_df['tweet_id'],
                 labels = train_df['label'],
                 predictions = train_predictions_multilayer_perceptron,
                 filepath_out = '../data/derived/tweets_supervised_train_predictions_multilayer_perceptron.csv')
save_predictions(tweet_ids = dev_df['tweet_id'],
                 labels = dev_df['label'],
                 predictions = dev_predictions_multilayer_perceptron,
                 filepath_out = '../data/derived/tweets_supervised_dev_predictions_multilayer_perceptron.csv')

# %% [markdown]
# ## Evaluate predictions

# %%
def evaluate_predictions(labels, predictions, filepath_out):
    """
    Calculate accuracy, confusion matrix, support, precision, recall and F1 score and write to CSV
    """
    
    # initialize empty dictionary to store metrics
    metrics = dict()
    
    # calculate and store confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_true = labels, y_pred = predictions).ravel()
    metrics['true_positives']  = tp
    metrics['false_positives'] = fp
    metrics['true_negatives']  = tn
    metrics['false_negatives'] = fn
    
    # calculate and store accuracy
    accuracy = (tp + fp) / (tp + fp + tn + fn)
    metrics['accuracy'] = (tp + tn) / (tp + tn + fp + fn)
    
    # calculate and store macro precision, recall and F1 score
    macro_precision, macro_recall, macro_f1, _ = precision_recall_fscore_support(y_true = labels,
                                                                                 y_pred = predictions,
                                                                                 average='macro')
    metrics['macro_recall']    = macro_recall
    metrics['macro_precision'] = macro_precision
    metrics['macro_f1']        = macro_f1
    
    # calculate and store micro precision, recall and F1 score
    micro_precision, micro_recall, micro_f1, _ = precision_recall_fscore_support(y_true = labels,
                                                                                 y_pred = predictions,
                                                                                 average='micro')
    metrics['micro_recall']    = micro_recall
    metrics['micro_precision'] = micro_precision
    metrics['micro_f1']        = micro_f1
    
    # calculate and store binary precision, recall and F1 score
    binary_precision, binary_recall, binary_f1, _ = precision_recall_fscore_support(y_true = labels,
                                                                                    y_pred = predictions,
                                                                                    average='binary')       
    metrics['binary_recall']    = binary_recall
    metrics['binary_precision'] = binary_precision
    metrics['binary_f1']        = binary_f1
    
    # create dataframe and write to CSV
    metrics_df = pd.DataFrame(data=list(metrics.items()), columns=['metric','value'])
    metrics_df.to_csv(path_or_buf=filepath_out, index=False)
    
    return metrics_df

# %%
# evaluate predictions for decision tree and write to CSV
train_metrics_decision_tree = evaluate_predictions(labels = train_df['label'],
                                                   predictions = train_predictions_decision_tree,
                                                   filepath_out = '../data/derived/performance_train_decision_tree.csv')
dev_metrics_decision_tree = evaluate_predictions(labels = dev_df['label'],
                                                 predictions = dev_predictions_decision_tree,
                                                 filepath_out = '../data/derived/performance_dev_decision_tree.csv')

# %%
# evaluate predictions for suport vector classifier and write to CSV
train_metrics_linear_svc = evaluate_predictions(labels = train_df['label'],
                                                predictions = train_predictions_linear_svc,
                                                filepath_out = '../data/derived/performance_train_linear_svc.csv')
dev_metrics_linear_svc = evaluate_predictions(labels = dev_df['label'],
                                              predictions = dev_predictions_linear_svc,
                                              filepath_out = '../data/derived/performance_dev_linear_svc.csv')

# %%
# evaluate predictions for multilayer perceptron and write to CSV
train_metrics_multilayer_perceptron = evaluate_predictions(labels = train_df['label'],
                                                           predictions = train_predictions_multilayer_perceptron,
                                                           filepath_out = '../data/derived/performance_train_multilayer_perceptron.csv')
dev_metrics_multilayer_perceptron = evaluate_predictions(labels = dev_df['label'],
                                                         predictions = dev_predictions_multilayer_perceptron,
                                                         filepath_out = '../data/derived/performance_dev_multilayer_perceptron.csv')

# %% [markdown]
# Check out evaluation metrics for training and development datasets for the decision tree classifier.

# %%
train_metrics_decision_tree
# Out:
#               metric   value
# 0     true_positives  2685.0
# 1    false_positives     0.0
# 2     true_negatives  3812.0
# 3    false_negatives     0.0
# 4           accuracy     1.0
# 5       macro_recall     1.0
# 6    macro_precision     1.0
# 7           macro_f1     1.0
# 8       micro_recall     1.0
# 9    micro_precision     1.0
# 10          micro_f1     1.0
# 11     binary_recall     1.0
# 12  binary_precision     1.0
# 13         binary_f1     1.0

# %%
dev_metrics_decision_tree
# Out:
#               metric       value
# 0     true_positives  463.000000
# 1    false_positives   86.000000
# 2     true_negatives  731.000000
# 3    false_negatives  113.000000
# 4           accuracy    0.857143
# 5       macro_recall    0.849278
# 6    macro_precision    0.854733
# 7           macro_f1    0.851652
# 8       micro_recall    0.857143
# 9    micro_precision    0.857143
# 10          micro_f1    0.857143
# 11     binary_recall    0.803819
# 12  binary_precision    0.843352
# 13         binary_f1    0.823111

# %% [markdown]
# Check out evaluation metrics for training and development datasets for the support vector classifier.

# %%
train_metrics_linear_svc
# Out:
#               metric        value
# 0     true_positives  2685.000000
# 1    false_positives     1.000000
# 2     true_negatives  3811.000000
# 3    false_negatives     0.000000
# 4           accuracy     0.999846
# 5       macro_recall     0.999869
# 6    macro_precision     0.999814
# 7           macro_f1     0.999841
# 8       micro_recall     0.999846
# 9    micro_precision     0.999846
# 10          micro_f1     0.999846
# 11     binary_recall     1.000000
# 12  binary_precision     0.999628
# 13         binary_f1     0.999814

# %%
dev_metrics_linear_svc
# Out:
#               metric       value
# 0     true_positives  486.000000
# 1    false_positives   50.000000
# 2     true_negatives  767.000000
# 3    false_negatives   90.000000
# 4           accuracy    0.899497
# 5       macro_recall    0.891275
# 6    macro_precision    0.900849
# 7           macro_f1    0.895234
# 8       micro_recall    0.899497
# 9    micro_precision    0.899497
# 10          micro_f1    0.899497
# 11     binary_recall    0.843750
# 12  binary_precision    0.906716
# 13         binary_f1    0.874101

# %% [markdown]
# Check out evaluation metrics for training and development datasets for the multilayer perceptron.

# %%
train_metrics_multilayer_perceptron
# Out:
#               metric   value
# 0     true_positives  2685.0
# 1    false_positives     0.0
# 2     true_negatives  3812.0
# 3    false_negatives     0.0
# 4           accuracy     1.0
# 5       macro_recall     1.0
# 6    macro_precision     1.0
# 7           macro_f1     1.0
# 8       micro_recall     1.0
# 9    micro_precision     1.0
# 10          micro_f1     1.0
# 11     binary_recall     1.0
# 12  binary_precision     1.0
# 13         binary_f1     1.0

# %%
dev_metrics_multilayer_perceptron
# Out:
#               metric       value
# 0     true_positives  487.000000
# 1    false_positives   55.000000
# 2     true_negatives  762.000000
# 3    false_negatives   89.000000
# 4           accuracy    0.896626
# 5       macro_recall    0.889083
# 6    macro_precision    0.896971
# 7           macro_f1    0.892434
# 8       micro_recall    0.896626
# 9    micro_precision    0.896626
# 10          micro_f1    0.896626
# 11     binary_recall    0.845486
# 12  binary_precision    0.898524
# 13         binary_f1    0.871199
